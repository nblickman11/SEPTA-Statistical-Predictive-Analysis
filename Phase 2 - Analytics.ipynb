# %%
# CONDITIONAL PROBABILITY AND PREDICTION MODELING

# %%
#imports
import pandas as pd
from pprint import pprint
import numpy as np
import csv
from datetime import datetime
import re
from matplotlib import pyplot as plt
from collections import defaultdict 
from collections import Counter
import spacy
nlp = spacy.load("en")

# %%
# CELL 1: LOAD, CLEAN AND SORT DATA

# load the data
with open("SEPTA_crm_export-2.csv", "r") as file:
    reader = csv.reader(file)
    data = list(reader)

# get only the tickets that have fully populated information (still over 100,000 of them).
NL = []
for lis in data[1:]:
    if len(lis) == 32:
        NL.append(lis)
        
# put into dataframe.
df = pd.DataFrame(NL, columns = data[0])

# create time stamps for the year variable
l = []
for item in df["customer_incident_date_time"]:
    if item:
        # turn the string into a datetime object
        dto = datetime.strptime(item, "%m/%d/%Y %H:%M:%S")
        l.append(dto)
    # if the data is empty, must keep length of dataframe the same
    else:
        l.append(None)
df["customer_incident_date_time"] = l

# sort the dataframe by timestamp. This helped understand our years with most of the info 2013 - 2020
df2 = df.sort_values(by = "customer_incident_date_time", axis = 0)
df3 = df2.reset_index(drop = True)

#check out the dataframe, the first and last several times are irrelevant and may not be used further.
df3
# Out:
#        cs_ticket_number how_received contact_id_c customer_incident_date_time  \
# 0                695025          Web                      0009-01-10 14:39:00
# 1                644376          Web                      0013-01-01 22:58:00
# 2                639009          Web                      0013-10-22 21:15:00
# 3                641783          Web                      0013-11-01 22:05:00
# 4                645464          Web                      0013-12-19 00:30:00
# ...                 ...          ...          ...                         ...
# 110208           765973          Web                                     None
# 110209           765702          Web                                     None
# 110210           765609          Web                                     None
# 110211           714555          Web                                     None
# 110212           765663          Web                                     None
#
#                      mode route         destination block_train  \
# 0                 Trolley   101               Media       train
# 1           Regional Rail   CHE  Chestnut Hill East
# 2                     CCT
# 3           Regional Rail   WIL
# 4                   SubEl
# ...                   ...   ...                 ...         ...
# 110208                  1     1                   1           1
# 110209                  1     1                   1           1
# 110210                                            1
# 110211
# 110212  1&n957679=v931268     1                   1           1
#
#                                       vehicle event  ...   esms titleiv  \
# 0                                                    ...  false   false
# 1                                        2760        ...  false   false
# 2                                    CCT  bus        ...  false   false
# 3                                        9243        ...  false   false
# 4                                                    ...  false   false
# ...                                       ...   ...  ...    ...     ...
# 110208                                      1        ...  false   false
# 110209  \+response.write(9822613*9424304)+\""        ...  false   false
# 110210                                               ...  false   false
# 110211                                               ...  false   false
# 110212                                      1        ...  false   false
#
#        protected_class         created_date          type                code  \
# 0                false  01/18/2015 05:57:00     Complaint     65-quality-life
# 1                false  12/11/2013 15:57:16  Commendation        C1-courteous
# 2                false  10/27/2013 22:46:22     Complaint     26-cct-same-day
# 3                false  11/18/2013 19:45:14     Complaint     65-quality-life
# 4                false  12/19/2013 14:13:11     Complaint  02-job-performance
# ...                ...                  ...           ...                 ...
# 110208           false  03/31/2016 18:41:19  Commendation
# 110209           false  03/31/2016 18:17:37     Complaint
# 110210           false  03/31/2016 18:10:05    Travelinfo
# 110211           false  06/04/2015 14:54:00    Travelinfo
# 110212           false  03/31/2016 18:14:45     Complaint
#
#            department  status     group_code          location
# 0         Other Depts  Closed  QualityOfLife            Police
# 1       Regional Rail  Closed       Employee               CHE
# 2                 CCT  Closed        Service               CCT
# 3        Cust Service  Closed  QualityOfLife  Customer Service
# 4               SubEl  Closed       Employee    SubEl Stations
# ...               ...     ...            ...               ...
# 110208                   Open
# 110209                   Open
# 110210                   Open
# 110211                   Open
# 110212                   Open
#
# [110213 rows x 32 columns]

# %%
# CELL 2:  PREDICTION MODELING: Length of Customer Complaints

# Below are the variables we want to predict (based on the length of a complaint in a customer ticket).
variables = ["ada_related", "detour_related", "weather_related", 
              "request_refund", "esms", "titleiv", "protected_class"]   
print() 
print("What is the likelihood the variable is true if the customer complaint is a certain length?")
for variable in variables:
    print()
    def prob(df3, complaint_len, variable):

        # First we must grab the total number of complaints that are longer than a specified threshold
        conditional_frame = df3[df3["customer_text_description"].str.len() >= complaint_len]
        total = len(conditional_frame)

        # Of that total, see if the variable we are predicting has value "true", for that ticket.
        both_true_frame = conditional_frame[conditional_frame[variable] == "true"]
        both_true = len(both_true_frame)

        likelihood = round(both_true/total, 2)
        
        
        print("If Length:", complaint_len, " Then", variable, likelihood)

    # iterate through the different lengths to apply to the customer complaint
    for i in [100, 300, 500, 750, 1000, 1500, 2000, 2500]:
        prob(df3, i, variable)   


# Analysis:  As the length of the complaint increases, so does the liklihood that the ticket has a purpose 
#...of being a request refund.  This makes sense !  A refund is a big deal and requires action from the...
#... company.  A customer making such a request would not surprisingly have a lot to say.
# Out:
# What is the likelihood the variable is true if the customer complaint is a certain length?
#
# If Length: 100  Then ada_related 0.01
# If Length: 300  Then ada_related 0.02
# If Length: 500  Then ada_related 0.02
# If Length: 750  Then ada_related 0.02
# If Length: 1000  Then ada_related 0.03
# If Length: 1500  Then ada_related 0.03
# If Length: 2000  Then ada_related 0.03
# If Length: 2500  Then ada_related 0.04
#
# If Length: 100  Then detour_related 0.01
# If Length: 300  Then detour_related 0.01
# If Length: 500  Then detour_related 0.02
# If Length: 750  Then detour_related 0.02
# If Length: 1000  Then detour_related 0.02
# If Length: 1500  Then detour_related 0.01
# If Length: 2000  Then detour_related 0.01
# If Length: 2500  Then detour_related 0.02
#
# If Length: 100  Then weather_related 0.02
# If Length: 300  Then weather_related 0.02
# If Length: 500  Then weather_related 0.02
# If Length: 750  Then weather_related 0.02
# If Length: 1000  Then weather_related 0.02
# If Length: 1500  Then weather_related 0.02
# If Length: 2000  Then weather_related 0.02
# If Length: 2500  Then weather_related 0.02
#
# If Length: 100  Then request_refund 0.02
# If Length: 300  Then request_refund 0.03
# If Length: 500  Then request_refund 0.04
# If Length: 750  Then request_refund 0.04
# If Length: 1000  Then request_refund 0.05
# If Length: 1500  Then request_refund 0.07
# If Length: 2000  Then request_refund 0.07
# If Length: 2500  Then request_refund 0.08
#
# If Length: 100  Then esms 0.0
# If Length: 300  Then esms 0.0
# If Length: 500  Then esms 0.0
# If Length: 750  Then esms 0.0
# If Length: 1000  Then esms 0.0
# If Length: 1500  Then esms 0.0
# If Length: 2000  Then esms 0.0
# If Length: 2500  Then esms 0.0
#
# If Length: 100  Then titleiv 0.0
# If Length: 300  Then titleiv 0.0
# If Length: 500  Then titleiv 0.0
# If Length: 750  Then titleiv 0.0
# If Length: 1000  Then titleiv 0.0
# If Length: 1500  Then titleiv 0.01
# If Length: 2000  Then titleiv 0.01
# If Length: 2500  Then titleiv 0.01
#
# If Length: 100  Then protected_class 0.0
# If Length: 300  Then protected_class 0.0
# If Length: 500  Then protected_class 0.0
# If Length: 750  Then protected_class 0.0
# If Length: 1000  Then protected_class 0.0
# If Length: 1500  Then protected_class 0.0
# If Length: 2000  Then protected_class 0.0
# If Length: 2500  Then protected_class 0.0

# %%
# CELL 3: Create Word Count for each Customer Complaint (will be inputs to CELL 4)

# 5 minute Run Time to create 10,000 counter structures

x = datetime.now()

# create word counts for each customer complaint ticket
def count_f(string):
    dd = defaultdict(int)
    doc = nlp(string)
    for token in doc:
        dd[token.text] += 1
    return dd

counters = df3["customer_text_description"][:10000].apply(count_f)

y = datetime.now()

print(y - x)
# Out:
# 0:04:39.965007

# %%
# CELL 4: PREDICTION MODELING:  Frequency of particular words in a complaint.

# Run Time 1 minute 30 seconds (with the 10,000 word count objects from Cell 3)

# we will check if the following "problem" words are in the customer complaint.
word_set = {"delays", "delayed", "delay", "problem", "problems", "guarantee", "sit", "however",
                   "please", "told", "not", "issue", "issues", "upset", "made", "angry", "harrassment",
                   "affecting"}

# variable we will try to predict.
variable = "ada_related"   

x = datetime.now()

for word in word_set:    
    def prob(df3, key_word, variable, counters):
        first_cond = 0
        sec_cond = 0
        index = 0
        
        # use our counter structure above to see if a key_word exists in a customer complaint.
        for counter in counters:
            total = 0
            index += 1
            for word, count, in counter.items():
                word = word.lower().strip()
                if word in key_word:
                    total = total + count
            
            # when a key_word exists in a complaint, check if our variable of that same ticket is true.
                # (in this case our variable is ada_related)
            if total > 0:
                first_cond += 1
                if df3[variable].iloc[index] == "true":
                    sec_cond += 1
        try:                   
            likelihood = round(sec_cond / first_cond, 2)
            print("If complaint had word:", key_word, "it has", likelihood, "chance to be", variable)
        except ZeroDivisionError:
            print("None were true")

    prob(df3, [word], variable, counters)   
    
y = datetime.now()
print(y - x)

# ANALYSIS:
#customer tickets with words like delayed, problems, and told, had a higher chance of being ADA related.
# Out:
# If complaint had word: ['delayed'] it has 0.02 chance to be ada_related
# If complaint had word: ['issues'] it has 0.0 chance to be ada_related
# If complaint had word: ['affecting'] it has 0.0 chance to be ada_related
# If complaint had word: ['delay'] it has 0.01 chance to be ada_related
# If complaint had word: ['made'] it has 0.01 chance to be ada_related
# If complaint had word: ['told'] it has 0.02 chance to be ada_related
# If complaint had word: ['problem'] it has 0.01 chance to be ada_related
# If complaint had word: ['sit'] it has 0.0 chance to be ada_related
# If complaint had word: ['not'] it has 0.01 chance to be ada_related
# If complaint had word: ['however'] it has 0.01 chance to be ada_related
# If complaint had word: ['issue'] it has 0.01 chance to be ada_related
# If complaint had word: ['delays'] it has 0.01 chance to be ada_related
# If complaint had word: ['upset'] it has 0.0 chance to be ada_related
# If complaint had word: ['angry'] it has 0.01 chance to be ada_related
# If complaint had word: ['please'] it has 0.01 chance to be ada_related
# If complaint had word: ['problems'] it has 0.02 chance to be ada_related
# If complaint had word: ['harrassment'] it has 0.0 chance to be ada_related
# If complaint had word: ['guarantee'] it has 0.0 chance to be ada_related
# 0:01:47.526043

# %%
# CELL 5: Get the Locations for each Customer Complaint (will be inputs to CELL 6)

# variables to predict based on location of ticket
variables = ["ada_related", "detour_related", "weather_related", "request_refund", 
             "esms", "titleiv", "protected_class"]  
        
# this code shows there are 83 TOTAL locations.
locations = []
for location in df3["location"]:
    if location not in locations:
        locations.append(location)

# lets count locations that actually have complaints
locations = Counter()
for typee,location in zip(df3["type"], df["location"]):
    if typee == "Complaint":
        locations[location] = locations[location] + 1
        
loc_l = []
count_l = []
for locs, counts in locations.items():
    # a couple locations were not locations, but sentences.
    if len(locs) < 100 and locs != "" and locs != " ":
        loc_l.append(locs)
        count_l.append(counts)

# %%
#CELL 6; PREDICTION MODELING: Location of Ticket

nest_dd = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))

#iterate through the customer tickets, check that tickets location, and check the variables we are predicting... 
    #... on that ticket are labeled "true" or "false". Append these items to our nested default dict.
for variable in variables:
    for location, related in zip(df3["location"], df3[variable]):
        # line below makes sure its a good location that has a minimum number of tickets
        if location in loc_l and locations[location] >=14:
            if related == 'true' or related == 'false':
                nest_dd[location][variable]['total'] = nest_dd[location][variable]['total'] + 1
            if related == 'true':
                nest_dd[location][variable]['true'] = nest_dd[location][variable]['true'] + 1
            if related == 'false':
                nest_dd[location][variable]['false'] = nest_dd[location][variable]['false'] + 1
                
pprint(nest_dd)
# Out:
# defaultdict(<function <lambda> at 0x7fb70d7fb320>,
#             {'AIR': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d0290>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 435,
#                                                              'total': 440,
#                                                              'true': 5}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 440,
#                                                                 'total': 440}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 440,
#                                                       'total': 440}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 440,
#                                                                  'total': 440}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 420,
#                                                                 'total': 440,
#                                                                 'true': 20}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 437,
#                                                          'total': 440,
#                                                          'true': 3}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 434,
#                                                                  'total': 440,
#                                                                  'true': 6})}),
#              'Allegheny Maint': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d97cd40>,
#                                             {'ada_related': defaultdict(<class 'int'>,
#                                                                         {'false': 158,
#                                                                          'total': 159,
#                                                                          'true': 1}),
#                                              'detour_related': defaultdict(<class 'int'>,
#                                                                            {'false': 159,
#                                                                             'total': 159}),
#                                              'esms': defaultdict(<class 'int'>,
#                                                                  {'false': 153,
#                                                                   'total': 159,
#                                                                   'true': 6}),
#                                              'protected_class': defaultdict(<class 'int'>,
#                                                                             {'false': 159,
#                                                                              'total': 159}),
#                                              'request_refund': defaultdict(<class 'int'>,
#                                                                            {'false': 159,
#                                                                             'total': 159}),
#                                              'titleiv': defaultdict(<class 'int'>,
#                                                                     {'false': 159,
#                                                                      'total': 159}),
#                                              'weather_related': defaultdict(<class 'int'>,
#                                                                             {'false': 158,
#                                                                              'total': 159,
#                                                                              'true': 1})}),
#              'Allegheny Trans': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d0830>,
#                                             {'ada_related': defaultdict(<class 'int'>,
#                                                                         {'false': 1895,
#                                                                          'total': 1942,
#                                                                          'true': 47}),
#                                              'detour_related': defaultdict(<class 'int'>,
#                                                                            {'false': 1891,
#                                                                             'total': 1942,
#                                                                             'true': 51}),
#                                              'esms': defaultdict(<class 'int'>,
#                                                                  {'false': 1942,
#                                                                   'total': 1942}),
#                                              'protected_class': defaultdict(<class 'int'>,
#                                                                             {'false': 1941,
#                                                                              'total': 1942,
#                                                                              'true': 1}),
#                                              'request_refund': defaultdict(<class 'int'>,
#                                                                            {'false': 1937,
#                                                                             'total': 1942,
#                                                                             'true': 5}),
#                                              'titleiv': defaultdict(<class 'int'>,
#                                                                     {'false': 1935,
#                                                                      'total': 1942,
#                                                                      'true': 7}),
#                                              'weather_related': defaultdict(<class 'int'>,
#                                                                             {'false': 1917,
#                                                                              'total': 1942,
#                                                                              'true': 25})}),
#              'BSL Maint': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d0b90>,
#                                       {'ada_related': defaultdict(<class 'int'>,
#                                                                   {'false': 267,
#                                                                    'total': 267}),
#                                        'detour_related': defaultdict(<class 'int'>,
#                                                                      {'false': 267,
#                                                                       'total': 267}),
#                                        'esms': defaultdict(<class 'int'>,
#                                                            {'false': 266,
#                                                             'total': 267,
#                                                             'true': 1}),
#                                        'protected_class': defaultdict(<class 'int'>,
#                                                                       {'false': 267,
#                                                                        'total': 267}),
#                                        'request_refund': defaultdict(<class 'int'>,
#                                                                      {'false': 261,
#                                                                       'total': 267,
#                                                                       'true': 6}),
#                                        'titleiv': defaultdict(<class 'int'>,
#                                                               {'false': 267,
#                                                                'total': 267}),
#                                        'weather_related': defaultdict(<class 'int'>,
#                                                                       {'false': 260,
#                                                                        'total': 267,
#                                                                        'true': 7})}),
#              'BSL Trans': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d0710>,
#                                       {'ada_related': defaultdict(<class 'int'>,
#                                                                   {'false': 764,
#                                                                    'total': 768,
#                                                                    'true': 4}),
#                                        'detour_related': defaultdict(<class 'int'>,
#                                                                      {'false': 768,
#                                                                       'total': 768}),
#                                        'esms': defaultdict(<class 'int'>,
#                                                            {'false': 768,
#                                                             'total': 768}),
#                                        'protected_class': defaultdict(<class 'int'>,
#                                                                       {'false': 768,
#                                                                        'total': 768}),
#                                        'request_refund': defaultdict(<class 'int'>,
#                                                                      {'false': 757,
#                                                                       'total': 768,
#                                                                       'true': 11}),
#                                        'titleiv': defaultdict(<class 'int'>,
#                                                               {'false': 768,
#                                                                'total': 768}),
#                                        'weather_related': defaultdict(<class 'int'>,
#                                                                       {'false': 765,
#                                                                        'total': 768,
#                                                                        'true': 3})}),
#              'CAL Rail Maint': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70db53560>,
#                                            {'ada_related': defaultdict(<class 'int'>,
#                                                                        {'false': 25,
#                                                                         'total': 26,
#                                                                         'true': 1}),
#                                             'detour_related': defaultdict(<class 'int'>,
#                                                                           {'false': 26,
#                                                                            'total': 26}),
#                                             'esms': defaultdict(<class 'int'>,
#                                                                 {'false': 26,
#                                                                  'total': 26}),
#                                             'protected_class': defaultdict(<class 'int'>,
#                                                                            {'false': 26,
#                                                                             'total': 26}),
#                                             'request_refund': defaultdict(<class 'int'>,
#                                                                           {'false': 26,
#                                                                            'total': 26}),
#                                             'titleiv': defaultdict(<class 'int'>,
#                                                                    {'false': 26,
#                                                                     'total': 26}),
#                                             'weather_related': defaultdict(<class 'int'>,
#                                                                            {'false': 26,
#                                                                             'total': 26})}),
#              'CCT': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d7fb200>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 1352,
#                                                              'total': 1385,
#                                                              'true': 33}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 1385,
#                                                                 'total': 1385}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 1384,
#                                                       'total': 1385,
#                                                       'true': 1}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 1385,
#                                                                  'total': 1385}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 1379,
#                                                                 'total': 1385,
#                                                                 'true': 6}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 1384,
#                                                          'total': 1385,
#                                                          'true': 1}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 1379,
#                                                                  'total': 1385,
#                                                                  'true': 6})}),
#              'CCT Eligibility': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d0dd0>,
#                                             {'ada_related': defaultdict(<class 'int'>,
#                                                                         {'false': 330,
#                                                                          'total': 375,
#                                                                          'true': 45}),
#                                              'detour_related': defaultdict(<class 'int'>,
#                                                                            {'false': 375,
#                                                                             'total': 375}),
#                                              'esms': defaultdict(<class 'int'>,
#                                                                  {'false': 375,
#                                                                   'total': 375}),
#                                              'protected_class': defaultdict(<class 'int'>,
#                                                                             {'false': 375,
#                                                                              'total': 375}),
#                                              'request_refund': defaultdict(<class 'int'>,
#                                                                            {'false': 375,
#                                                                             'total': 375}),
#                                              'titleiv': defaultdict(<class 'int'>,
#                                                                     {'false': 375,
#                                                                      'total': 375}),
#                                              'weather_related': defaultdict(<class 'int'>,
#                                                                             {'false': 375,
#                                                                              'total': 375})}),
#              'CHE': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d736440>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 677,
#                                                              'total': 681,
#                                                              'true': 4}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 681,
#                                                                 'total': 681}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 681,
#                                                       'total': 681}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 681,
#                                                                  'total': 681}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 678,
#                                                                 'total': 681,
#                                                                 'true': 3}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 681,
#                                                          'total': 681}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 672,
#                                                                  'total': 681,
#                                                                  'true': 9})}),
#              'CHW': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d97cc20>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 542,
#                                                              'total': 548,
#                                                              'true': 6}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 548,
#                                                                 'total': 548}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 547,
#                                                       'total': 548,
#                                                       'true': 1}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 548,
#                                                                  'total': 548}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 540,
#                                                                 'total': 548,
#                                                                 'true': 8}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 546,
#                                                          'total': 548,
#                                                          'true': 2}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 532,
#                                                                  'total': 548,
#                                                                  'true': 16})}),
#              'CYN': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d7fbef0>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 45,
#                                                              'total': 46,
#                                                              'true': 1}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 46,
#                                                                 'total': 46}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 46,
#                                                       'total': 46}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 46,
#                                                                  'total': 46}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 46,
#                                                                 'total': 46}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 46,
#                                                          'total': 46}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 45,
#                                                                  'total': 46,
#                                                                  'true': 1})}),
#              'Callowhill Maint': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d97c290>,
#                                              {'ada_related': defaultdict(<class 'int'>,
#                                                                          {'false': 144,
#                                                                           'total': 145,
#                                                                           'true': 1}),
#                                               'detour_related': defaultdict(<class 'int'>,
#                                                                             {'false': 145,
#                                                                              'total': 145}),
#                                               'esms': defaultdict(<class 'int'>,
#                                                                   {'false': 140,
#                                                                    'total': 145,
#                                                                    'true': 5}),
#                                               'protected_class': defaultdict(<class 'int'>,
#                                                                              {'false': 145,
#                                                                               'total': 145}),
#                                               'request_refund': defaultdict(<class 'int'>,
#                                                                             {'false': 145,
#                                                                              'total': 145}),
#                                               'titleiv': defaultdict(<class 'int'>,
#                                                                      {'false': 145,
#                                                                       'total': 145}),
#                                               'weather_related': defaultdict(<class 'int'>,
#                                                                              {'false': 144,
#                                                                               'total': 145,
#                                                                               'true': 1})}),
#              'Callowhill Trans': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d97c200>,
#                                              {'ada_related': defaultdict(<class 'int'>,
#                                                                          {'false': 3033,
#                                                                           'total': 3120,
#                                                                           'true': 87}),
#                                               'detour_related': defaultdict(<class 'int'>,
#                                                                             {'false': 3071,
#                                                                              'total': 3120,
#                                                                              'true': 49}),
#                                               'esms': defaultdict(<class 'int'>,
#                                                                   {'false': 3111,
#                                                                    'total': 3120,
#                                                                    'true': 9}),
#                                               'protected_class': defaultdict(<class 'int'>,
#                                                                              {'false': 3118,
#                                                                               'total': 3120,
#                                                                               'true': 2}),
#                                               'request_refund': defaultdict(<class 'int'>,
#                                                                             {'false': 3113,
#                                                                              'total': 3120,
#                                                                              'true': 7}),
#                                               'titleiv': defaultdict(<class 'int'>,
#                                                                      {'false': 3111,
#                                                                       'total': 3120,
#                                                                       'true': 9}),
#                                               'weather_related': defaultdict(<class 'int'>,
#                                                                              {'false': 3080,
#                                                                               'total': 3120,
#                                                                               'true': 40})}),
#              'Claims': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d00e0>,
#                                    {'ada_related': defaultdict(<class 'int'>,
#                                                                {'false': 963,
#                                                                 'total': 980,
#                                                                 'true': 17}),
#                                     'detour_related': defaultdict(<class 'int'>,
#                                                                   {'false': 978,
#                                                                    'total': 980,
#                                                                    'true': 2}),
#                                     'esms': defaultdict(<class 'int'>,
#                                                         {'false': 971,
#                                                          'total': 980,
#                                                          'true': 9}),
#                                     'protected_class': defaultdict(<class 'int'>,
#                                                                    {'false': 979,
#                                                                     'total': 980,
#                                                                     'true': 1}),
#                                     'request_refund': defaultdict(<class 'int'>,
#                                                                   {'false': 975,
#                                                                    'total': 980,
#                                                                    'true': 5}),
#                                     'titleiv': defaultdict(<class 'int'>,
#                                                            {'false': 979,
#                                                             'total': 980,
#                                                             'true': 1}),
#                                     'weather_related': defaultdict(<class 'int'>,
#                                                                    {'false': 960,
#                                                                     'total': 980,
#                                                                     'true': 20})}),
#              'Comly Maint': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70db53200>,
#                                         {'ada_related': defaultdict(<class 'int'>,
#                                                                     {'false': 159,
#                                                                      'total': 161,
#                                                                      'true': 2}),
#                                          'detour_related': defaultdict(<class 'int'>,
#                                                                        {'false': 161,
#                                                                         'total': 161}),
#                                          'esms': defaultdict(<class 'int'>,
#                                                              {'false': 154,
#                                                               'total': 161,
#                                                               'true': 7}),
#                                          'protected_class': defaultdict(<class 'int'>,
#                                                                         {'false': 161,
#                                                                          'total': 161}),
#                                          'request_refund': defaultdict(<class 'int'>,
#                                                                        {'false': 160,
#                                                                         'total': 161,
#                                                                         'true': 1}),
#                                          'titleiv': defaultdict(<class 'int'>,
#                                                                 {'false': 161,
#                                                                  'total': 161}),
#                                          'weather_related': defaultdict(<class 'int'>,
#                                                                         {'false': 158,
#                                                                          'total': 161,
#                                                                          'true': 3})}),
#              'Comly Trans': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d0440>,
#                                         {'ada_related': defaultdict(<class 'int'>,
#                                                                     {'false': 2478,
#                                                                      'total': 2549,
#                                                                      'true': 71}),
#                                          'detour_related': defaultdict(<class 'int'>,
#                                                                        {'false': 2536,
#                                                                         'total': 2549,
#                                                                         'true': 13}),
#                                          'esms': defaultdict(<class 'int'>,
#                                                              {'false': 2546,
#                                                               'total': 2549,
#                                                               'true': 3}),
#                                          'protected_class': defaultdict(<class 'int'>,
#                                                                         {'false': 2542,
#                                                                          'total': 2549,
#                                                                          'true': 7}),
#                                          'request_refund': defaultdict(<class 'int'>,
#                                                                        {'false': 2544,
#                                                                         'total': 2549,
#                                                                         'true': 5}),
#                                          'titleiv': defaultdict(<class 'int'>,
#                                                                 {'false': 2535,
#                                                                  'total': 2549,
#                                                                  'true': 14}),
#                                          'weather_related': defaultdict(<class 'int'>,
#                                                                         {'false': 2515,
#                                                                          'total': 2549,
#                                                                          'true': 34})}),
#              'Communications': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70db530e0>,
#                                            {'ada_related': defaultdict(<class 'int'>,
#                                                                        {'false': 319,
#                                                                         'total': 323,
#                                                                         'true': 4}),
#                                             'detour_related': defaultdict(<class 'int'>,
#                                                                           {'false': 321,
#                                                                            'total': 323,
#                                                                            'true': 2}),
#                                             'esms': defaultdict(<class 'int'>,
#                                                                 {'false': 323,
#                                                                  'total': 323}),
#                                             'protected_class': defaultdict(<class 'int'>,
#                                                                            {'false': 323,
#                                                                             'total': 323}),
#                                             'request_refund': defaultdict(<class 'int'>,
#                                                                           {'false': 323,
#                                                                            'total': 323}),
#                                             'titleiv': defaultdict(<class 'int'>,
#                                                                    {'false': 323,
#                                                                     'total': 323}),
#                                             'weather_related': defaultdict(<class 'int'>,
#                                                                            {'false': 323,
#                                                                             'total': 323})}),
#              'Contract Ops': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d0a70>,
#                                          {'ada_related': defaultdict(<class 'int'>,
#                                                                      {'false': 489,
#                                                                       'total': 494,
#                                                                       'true': 5}),
#                                           'detour_related': defaultdict(<class 'int'>,
#                                                                         {'false': 494,
#                                                                          'total': 494}),
#                                           'esms': defaultdict(<class 'int'>,
#                                                               {'false': 491,
#                                                                'total': 494,
#                                                                'true': 3}),
#                                           'protected_class': defaultdict(<class 'int'>,
#                                                                          {'false': 494,
#                                                                           'total': 494}),
#                                           'request_refund': defaultdict(<class 'int'>,
#                                                                         {'false': 494,
#                                                                          'total': 494}),
#                                           'titleiv': defaultdict(<class 'int'>,
#                                                                  {'false': 494,
#                                                                   'total': 494}),
#                                           'weather_related': defaultdict(<class 'int'>,
#                                                                          {'false': 488,
#                                                                           'total': 494,
#                                                                           'true': 6})}),
#              'Control Center': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d97c320>,
#                                            {'ada_related': defaultdict(<class 'int'>,
#                                                                        {'false': 1386,
#                                                                         'total': 1388,
#                                                                         'true': 2}),
#                                             'detour_related': defaultdict(<class 'int'>,
#                                                                           {'false': 1370,
#                                                                            'total': 1388,
#                                                                            'true': 18}),
#                                             'esms': defaultdict(<class 'int'>,
#                                                                 {'false': 1388,
#                                                                  'total': 1388}),
#                                             'protected_class': defaultdict(<class 'int'>,
#                                                                            {'false': 1388,
#                                                                             'total': 1388}),
#                                             'request_refund': defaultdict(<class 'int'>,
#                                                                           {'false': 1363,
#                                                                            'total': 1388,
#                                                                            'true': 25}),
#                                             'titleiv': defaultdict(<class 'int'>,
#                                                                    {'false': 1388,
#                                                                     'total': 1388}),
#                                             'weather_related': defaultdict(<class 'int'>,
#                                                                            {'false': 1310,
#                                                                             'total': 1388,
#                                                                             'true': 78})}),
#              'Customer Service': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d7fb440>,
#                                              {'ada_related': defaultdict(<class 'int'>,
#                                                                          {'false': 21325,
#                                                                           'total': 21452,
#                                                                           'true': 127}),
#                                               'detour_related': defaultdict(<class 'int'>,
#                                                                             {'false': 21226,
#                                                                              'total': 21452,
#                                                                              'true': 226}),
#                                               'esms': defaultdict(<class 'int'>,
#                                                                   {'false': 21438,
#                                                                    'total': 21452,
#                                                                    'true': 14}),
#                                               'protected_class': defaultdict(<class 'int'>,
#                                                                              {'false': 21450,
#                                                                               'total': 21452,
#                                                                               'true': 2}),
#                                               'request_refund': defaultdict(<class 'int'>,
#                                                                             {'false': 20998,
#                                                                              'total': 21452,
#                                                                              'true': 454}),
#                                               'titleiv': defaultdict(<class 'int'>,
#                                                                      {'false': 21444,
#                                                                       'total': 21452,
#                                                                       'true': 8}),
#                                               'weather_related': defaultdict(<class 'int'>,
#                                                                              {'false': 21220,
#                                                                               'total': 21452,
#                                                                               'true': 232})}),
#              'DOY': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d7fb7a0>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 1941,
#                                                              'total': 1958,
#                                                              'true': 17}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 1958,
#                                                                 'total': 1958}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 1957,
#                                                       'total': 1958,
#                                                       'true': 1}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 1958,
#                                                                  'total': 1958}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 1916,
#                                                                 'total': 1958,
#                                                                 'true': 42}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 1958,
#                                                          'total': 1958}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 1936,
#                                                                  'total': 1958,
#                                                                  'true': 22})}),
#              'ELW': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d97c440>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 1283,
#                                                              'total': 1297,
#                                                              'true': 14}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 1297,
#                                                                 'total': 1297}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 1296,
#                                                       'total': 1297,
#                                                       'true': 1}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 1296,
#                                                                  'total': 1297,
#                                                                  'true': 1}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 1271,
#                                                                 'total': 1297,
#                                                                 'true': 26}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 1294,
#                                                          'total': 1297,
#                                                          'true': 3}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 1272,
#                                                                  'total': 1297,
#                                                                  'true': 25})}),
#              'EM & C': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d08c0>,
#                                    {'ada_related': defaultdict(<class 'int'>,
#                                                                {'false': 2457,
# ...
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 1461,
#                                                                  'total': 1484,
#                                                                  'true': 23})}),
#              'Victory Maint': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70db53170>,
#                                           {'ada_related': defaultdict(<class 'int'>,
#                                                                       {'false': 196,
#                                                                        'total': 198,
#                                                                        'true': 2}),
#                                            'detour_related': defaultdict(<class 'int'>,
#                                                                          {'false': 197,
#                                                                           'total': 198,
#                                                                           'true': 1}),
#                                            'esms': defaultdict(<class 'int'>,
#                                                                {'false': 190,
#                                                                 'total': 198,
#                                                                 'true': 8}),
#                                            'protected_class': defaultdict(<class 'int'>,
#                                                                           {'false': 198,
#                                                                            'total': 198}),
#                                            'request_refund': defaultdict(<class 'int'>,
#                                                                          {'false': 196,
#                                                                           'total': 198,
#                                                                           'true': 2}),
#                                            'titleiv': defaultdict(<class 'int'>,
#                                                                   {'false': 198,
#                                                                    'total': 198}),
#                                            'weather_related': defaultdict(<class 'int'>,
#                                                                           {'false': 193,
#                                                                            'total': 198,
#                                                                            'true': 5})}),
#              'Victory Service': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70db535f0>,
#                                             {'ada_related': defaultdict(<class 'int'>,
#                                                                         {'false': 1967,
#                                                                          'total': 1978,
#                                                                          'true': 11}),
#                                              'detour_related': defaultdict(<class 'int'>,
#                                                                            {'false': 1940,
#                                                                             'total': 1978,
#                                                                             'true': 38}),
#                                              'esms': defaultdict(<class 'int'>,
#                                                                  {'false': 1976,
#                                                                   'total': 1978,
#                                                                   'true': 2}),
#                                              'protected_class': defaultdict(<class 'int'>,
#                                                                             {'false': 1978,
#                                                                              'total': 1978}),
#                                              'request_refund': defaultdict(<class 'int'>,
#                                                                            {'false': 1966,
#                                                                             'total': 1978,
#                                                                             'true': 12}),
#                                              'titleiv': defaultdict(<class 'int'>,
#                                                                     {'false': 1978,
#                                                                      'total': 1978}),
#                                              'weather_related': defaultdict(<class 'int'>,
#                                                                             {'false': 1960,
#                                                                              'total': 1978,
#                                                                              'true': 18})}),
#              'Victory Trans': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d7fbdd0>,
#                                           {'ada_related': defaultdict(<class 'int'>,
#                                                                       {'false': 3046,
#                                                                        'total': 3105,
#                                                                        'true': 59}),
#                                            'detour_related': defaultdict(<class 'int'>,
#                                                                          {'false': 3093,
#                                                                           'total': 3105,
#                                                                           'true': 12}),
#                                            'esms': defaultdict(<class 'int'>,
#                                                                {'false': 3103,
#                                                                 'total': 3105,
#                                                                 'true': 2}),
#                                            'protected_class': defaultdict(<class 'int'>,
#                                                                           {'false': 3104,
#                                                                            'total': 3105,
#                                                                            'true': 1}),
#                                            'request_refund': defaultdict(<class 'int'>,
#                                                                          {'false': 3090,
#                                                                           'total': 3105,
#                                                                           'true': 15}),
#                                            'titleiv': defaultdict(<class 'int'>,
#                                                                   {'false': 3095,
#                                                                    'total': 3105,
#                                                                    'true': 10}),
#                                            'weather_related': defaultdict(<class 'int'>,
#                                                                           {'false': 3055,
#                                                                            'total': 3105,
#                                                                            'true': 50})}),
#              'WAR': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d0320>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 1642,
#                                                              'total': 1657,
#                                                              'true': 15}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 1657,
#                                                                 'total': 1657}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 1655,
#                                                       'total': 1657,
#                                                       'true': 2}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 1657,
#                                                                  'total': 1657}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 1627,
#                                                                 'total': 1657,
#                                                                 'true': 30}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 1656,
#                                                          'total': 1657,
#                                                          'true': 1}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 1635,
#                                                                  'total': 1657,
#                                                                  'true': 22})}),
#              'WIL': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d97c680>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 1213,
#                                                              'total': 1228,
#                                                              'true': 15}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 1228,
#                                                                 'total': 1228}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 1227,
#                                                       'total': 1228,
#                                                       'true': 1}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 1228,
#                                                                  'total': 1228}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 1197,
#                                                                 'total': 1228,
#                                                                 'true': 31}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 1226,
#                                                          'total': 1228,
#                                                          'true': 2}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 1201,
#                                                                  'total': 1228,
#                                                                  'true': 27})}),
#              'WTR': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d97c830>,
#                                 {'ada_related': defaultdict(<class 'int'>,
#                                                             {'false': 1656,
#                                                              'total': 1673,
#                                                              'true': 17}),
#                                  'detour_related': defaultdict(<class 'int'>,
#                                                                {'false': 1673,
#                                                                 'total': 1673}),
#                                  'esms': defaultdict(<class 'int'>,
#                                                      {'false': 1673,
#                                                       'total': 1673}),
#                                  'protected_class': defaultdict(<class 'int'>,
#                                                                 {'false': 1673,
#                                                                  'total': 1673}),
#                                  'request_refund': defaultdict(<class 'int'>,
#                                                                {'false': 1644,
#                                                                 'total': 1673,
#                                                                 'true': 29}),
#                                  'titleiv': defaultdict(<class 'int'>,
#                                                         {'false': 1672,
#                                                          'total': 1673,
#                                                          'true': 1}),
#                                  'weather_related': defaultdict(<class 'int'>,
#                                                                 {'false': 1648,
#                                                                  'total': 1673,
#                                                                  'true': 25})}),
#              'Wyoming': defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fb70d8d09e0>,
#                                     {'ada_related': defaultdict(<class 'int'>,
#                                                                 {'false': 10258,
#                                                                  'total': 10282,
#                                                                  'true': 24}),
#                                      'detour_related': defaultdict(<class 'int'>,
#                                                                    {'false': 9616,
#                                                                     'total': 10282,
#                                                                     'true': 666}),
#                                      'esms': defaultdict(<class 'int'>,
#                                                          {'false': 10280,
#                                                           'total': 10282,
#                                                           'true': 2}),
#                                      'protected_class': defaultdict(<class 'int'>,
#                                                                     {'false': 10280,
#                                                                      'total': 10282,
#                                                                      'true': 2}),
#                                      'request_refund': defaultdict(<class 'int'>,
#                                                                    {'false': 10237,
#                                                                     'total': 10282,
#                                                                     'true': 45}),
#                                      'titleiv': defaultdict(<class 'int'>,
#                                                             {'false': 10282,
#                                                              'total': 10282}),
#                                      'weather_related': defaultdict(<class 'int'>,
#                                                                     {'false': 10194,
#                                                                      'total': 10282,
#                                                                      'true': 88})})})

# %%
# CELL 7: PREDICTION MODELING: Location of Ticket CONTINUED

correlations = []

# now we can iterate through our nested default dictionary in order to count up, based on the location of 
    #... the ticket, how many times a variable is "true".  
for location, dd in nest_dd.items():
    for variable, dd2 in dd.items():
        for t_f_tot, count in list(dd2.items()):
            l = []
            l.append(location)
            l.append(variable)
            
            # calculate our percentage to see how likely a variable is to be true if its from a location.
                # dd2["total"] is the total amount of tickets from a particular location.
                # dd2["true"] is the number of tickets labeled "true" for a particular variable.
            l.append(round(dd2["true"]/dd2["total"], 3))
            t = tuple(l)
            correlations.append(t)

sorted(correlations, key =lambda x: x[2], reverse = True)     

# Lets check out the highest correlations between Location and type (Variable) of the customer ticket.

# If the location of the ticket is from "Sales", "Septa Key Call Center", or "Revenue Operations",
    #... we can see it is much more likely to be a request refund related ticket !
# Out:
# [('Sales', 'request_refund', 0.416),
#  ('Sales', 'request_refund', 0.416),
#  ('Sales', 'request_refund', 0.416),
#  ('Septa Key Call Center', 'request_refund', 0.412),
#  ('Septa Key Call Center', 'request_refund', 0.412),
#  ('Septa Key Call Center', 'request_refund', 0.412),
#  ('Revenue Operations', 'request_refund', 0.207),
#  ('Revenue Operations', 'request_refund', 0.207),
#  ('Revenue Operations', 'request_refund', 0.207),
#  ('RR Rev', 'request_refund', 0.194),
#  ('RR Rev', 'request_refund', 0.194),
#  ('RR Rev', 'request_refund', 0.194),
#  ('CCT Eligibility', 'ada_related', 0.12),
#  ('CCT Eligibility', 'ada_related', 0.12),
#  ('CCT Eligibility', 'ada_related', 0.12),
#  ('EM & C', 'weather_related', 0.115),
#  ('EM & C', 'weather_related', 0.115),
#  ('EM & C', 'weather_related', 0.115),
#  ('Wyoming', 'detour_related', 0.065),
#  ('Wyoming', 'detour_related', 0.065),
#  ('Wyoming', 'detour_related', 0.065),
#  ('Control Center', 'weather_related', 0.056),
#  ('Control Center', 'weather_related', 0.056),
#  ('Control Center', 'weather_related', 0.056),
#  ('Frontier Maint', 'weather_related', 0.056),
#  ('Frontier Maint', 'weather_related', 0.056),
#  ('Frontier Maint', 'weather_related', 0.056),
#  ('IG', 'titleiv', 0.056),
#  ('IG', 'titleiv', 0.056),
#  ('IG', 'titleiv', 0.056),
#  ('Southern Maint', 'esms', 0.047),
#  ('Southern Maint', 'esms', 0.047),
#  ('Southern Maint', 'esms', 0.047),
#  ('AIR', 'request_refund', 0.045),
#  ('AIR', 'request_refund', 0.045),
#  ('AIR', 'request_refund', 0.045),
#  ('Comly Maint', 'esms', 0.043),
#  ('Comly Maint', 'esms', 0.043),
#  ('Comly Maint', 'esms', 0.043),
#  ('Frontier Maint', 'esms', 0.042),
#  ('Frontier Maint', 'esms', 0.042),
#  ('Frontier Maint', 'esms', 0.042),
#  ('Victory Maint', 'esms', 0.04),
#  ('Victory Maint', 'esms', 0.04),
#  ('Victory Maint', 'esms', 0.04),
#  ('Allegheny Maint', 'esms', 0.038),
#  ('Allegheny Maint', 'esms', 0.038),
#  ('Allegheny Maint', 'esms', 0.038),
#  ('CAL Rail Maint', 'ada_related', 0.038),
#  ('CAL Rail Maint', 'ada_related', 0.038),
#  ('CAL Rail Maint', 'ada_related', 0.038),
#  ('RR Maint', 'weather_related', 0.035),
#  ('RR Maint', 'weather_related', 0.035),
#  ('RR Maint', 'weather_related', 0.035),
#  ('Public/Gov. Affairs', 'ada_related', 0.034),
#  ('Public/Gov. Affairs', 'ada_related', 0.034),
#  ('Public/Gov. Affairs', 'ada_related', 0.034),
#  ('Callowhill Maint', 'esms', 0.034),
#  ('Callowhill Maint', 'esms', 0.034),
#  ('Callowhill Maint', 'esms', 0.034),
#  ('PAO', 'request_refund', 0.029),
#  ('PAO', 'request_refund', 0.029),
#  ('PAO', 'request_refund', 0.029),
#  ('EM & C', 'ada_related', 0.029),
#  ('EM & C', 'ada_related', 0.029),
#  ('EM & C', 'ada_related', 0.029),
#  ('NOR', 'weather_related', 0.029),
#  ('NOR', 'weather_related', 0.029),
#  ('NOR', 'weather_related', 0.029),
#  ('CHW', 'weather_related', 0.029),
#  ('CHW', 'weather_related', 0.029),
#  ('CHW', 'weather_related', 0.029),
#  ('MED Sh Maint', 'esms', 0.029),
#  ('MED Sh Maint', 'esms', 0.029),
#  ('MED Sh Maint', 'esms', 0.029),
#  ('TRE', 'request_refund', 0.028),
#  ('TRE', 'request_refund', 0.028),
#  ('TRE', 'request_refund', 0.028),
#  ('Comly Trans', 'ada_related', 0.028),
#  ('Comly Trans', 'ada_related', 0.028),
#  ('Comly Trans', 'ada_related', 0.028),
#  ('Callowhill Trans', 'ada_related', 0.028),
#  ('Callowhill Trans', 'ada_related', 0.028),
#  ('Callowhill Trans', 'ada_related', 0.028),
#  ('Frontier Maint', 'request_refund', 0.028),
#  ('Frontier Maint', 'request_refund', 0.028),
#  ('Frontier Maint', 'request_refund', 0.028),
#  ('FOX', 'weather_related', 0.028),
#  ('FOX', 'weather_related', 0.028),
#  ('FOX', 'weather_related', 0.028),
#  ('Southern Trans', 'detour_related', 0.027),
#  ('Southern Trans', 'detour_related', 0.027),
#  ('Southern Trans', 'detour_related', 0.027),
#  ('EM & C', 'esms', 0.027),
#  ('EM & C', 'esms', 0.027),
#  ('EM & C', 'esms', 0.027),
#  ('NHSL Maint', 'ada_related', 0.027),
#  ('NHSL Maint', 'ada_related', 0.027),
#  ('NHSL Maint', 'ada_related', 0.027),
#  ('NHSL Maint', 'weather_related', 0.027),
#  ('NHSL Maint', 'weather_related', 0.027),
#  ('NHSL Maint', 'weather_related', 0.027),
#  ('NHSL Maint', 'request_refund', 0.027),
#  ('NHSL Maint', 'request_refund', 0.027),
#  ('NHSL Maint', 'request_refund', 0.027),
#  ('Frontier Service', 'detour_related', 0.027),
#  ('Frontier Service', 'detour_related', 0.027),
#  ('Frontier Service', 'detour_related', 0.027),
#  ('Allegheny Trans', 'detour_related', 0.026),
#  ('Allegheny Trans', 'detour_related', 0.026),
#  ('Allegheny Trans', 'detour_related', 0.026),
#  ('BSL Maint', 'weather_related', 0.026),
#  ('BSL Maint', 'weather_related', 0.026),
#  ('BSL Maint', 'weather_related', 0.026),
#  ('SubEl Stations', 'request_refund', 0.025),
#  ('SubEl Stations', 'request_refund', 0.025),
#  ('SubEl Stations', 'request_refund', 0.025),
#  ('Southern Trans', 'ada_related', 0.025),
#  ('Southern Trans', 'ada_related', 0.025),
#  ('Southern Trans', 'ada_related', 0.025),
#  ('WIL', 'request_refund', 0.025),
#  ('WIL', 'request_refund', 0.025),
#  ('WIL', 'request_refund', 0.025),
#  ('Midvale Maint', 'weather_related', 0.025),
#  ('Midvale Maint', 'weather_related', 0.025),
#  ('Midvale Maint', 'weather_related', 0.025),
#  ('Victory Maint', 'weather_related', 0.025),
#  ('Victory Maint', 'weather_related', 0.025),
#  ('Victory Maint', 'weather_related', 0.025),
#  ('CCT', 'ada_related', 0.024),
#  ('CCT', 'ada_related', 0.024),
#  ('CCT', 'ada_related', 0.024),
#  ('Frankford Trans', 'ada_related', 0.024),
#  ('Frankford Trans', 'ada_related', 0.024),
#  ('Frankford Trans', 'ada_related', 0.024),
#  ('Allegheny Trans', 'ada_related', 0.024),
#  ('Allegheny Trans', 'ada_related', 0.024),
#  ('Allegheny Trans', 'ada_related', 0.024),
#  ('Elmwood Maint', 'weather_related', 0.024),
#  ('Elmwood Maint', 'weather_related', 0.024),
#  ('Elmwood Maint', 'weather_related', 0.024),
#  ('NOR', 'request_refund', 0.023),
#  ('NOR', 'request_refund', 0.023),
#  ('NOR', 'request_refund', 0.023),
#  ('Midvale Trans', 'ada_related', 0.022),
#  ('Midvale Trans', 'ada_related', 0.022),
#  ('Midvale Trans', 'ada_related', 0.022),
#  ('CYN', 'ada_related', 0.022),
#  ('CYN', 'ada_related', 0.022),
#  ('CYN', 'ada_related', 0.022),
#  ('CYN', 'weather_related', 0.022),
#  ('CYN', 'weather_related', 0.022),
#  ('CYN', 'weather_related', 0.022),
#  ('Key Development', 'ada_related', 0.022),
#  ('Key Development', 'ada_related', 0.022),
#  ('Key Development', 'ada_related', 0.022),
#  ('Frontier Trans', 'ada_related', 0.022),
#  ('Frontier Trans', 'ada_related', 0.022),
#  ('Frontier Trans', 'ada_related', 0.022),
#  ('BSL Maint', 'request_refund', 0.022),
#  ('BSL Maint', 'request_refund', 0.022),
#  ('BSL Maint', 'request_refund', 0.022),
#  ('WIL', 'weather_related', 0.022),
#  ('WIL', 'weather_related', 0.022),
#  ('WIL', 'weather_related', 0.022),
#  ('Customer Service', 'request_refund', 0.021),
#  ('Customer Service', 'request_refund', 0.021),
#  ('Customer Service', 'request_refund', 0.021),
#  ('DOY', 'request_refund', 0.021),
#  ('DOY', 'request_refund', 0.021),
#  ('DOY', 'request_refund', 0.021),
#  ('Claims', 'weather_related', 0.02),
#  ('Claims', 'weather_related', 0.02),
#  ('Claims', 'weather_related', 0.02),
#  ('Key Development', 'request_refund', 0.02),
#  ('Key Development', 'request_refund', 0.02),
#  ('Key Development', 'request_refund', 0.02),
#  ('ELW', 'request_refund', 0.02),
#  ('ELW', 'request_refund', 0.02),
#  ('ELW', 'request_refund', 0.02),
#  ('Victory Trans', 'ada_related', 0.019),
#  ('Victory Trans', 'ada_related', 0.019),
#  ('Victory Trans', 'ada_related', 0.019),
#  ('Serv Plan RR', 'weather_related', 0.019),
#  ('Serv Plan RR', 'weather_related', 0.019),
#  ('Serv Plan RR', 'weather_related', 0.019),
#  ('ELW', 'weather_related', 0.019),
#  ('ELW', 'weather_related', 0.019),
#  ('ELW', 'weather_related', 0.019),
#  ('RR Maint', 'request_refund', 0.019),
#  ('RR Maint', 'request_refund', 0.019),
#  ('RR Maint', 'request_refund', 0.019),
#  ('Comly Maint', 'weather_related', 0.019),
#  ('Comly Maint', 'weather_related', 0.019),
#  ('Comly Maint', 'weather_related', 0.019),
#  ('Victory Service', 'detour_related', 0.019),
#  ('Victory Service', 'detour_related', 0.019),
#  ('Victory Service', 'detour_related', 0.019),
#  ('SubEl Stations', 'ada_related', 0.018),
#  ('SubEl Stations', 'ada_related', 0.018),
#  ('SubEl Stations', 'ada_related', 0.018),
#  ('Midvale Trans', 'weather_related', 0.018),
#  ('Midvale Trans', 'weather_related', 0.018),
#  ('Midvale Trans', 'weather_related', 0.018),
#  ('WAR', 'request_refund', 0.018),
#  ('WAR', 'request_refund', 0.018),
#  ('WAR', 'request_refund', 0.018),
#  ('PAO', 'weather_related', 0.018),
#  ('PAO', 'weather_related', 0.018),
#  ('PAO', 'weather_related', 0.018),
#  ('Parking Operations', 'ada_related', 0.018),
#  ('Parking Operations', 'ada_related', 0.018),
#  ('Parking Operations', 'ada_related', 0.018),
#  ('Control Center', 'request_refund', 0.018),
#  ('Control Center', 'request_refund', 0.018),
#  ('Control Center', 'request_refund', 0.018),
#  ('Elmwood Trans', 'ada_related', 0.018),
#  ('Elmwood Trans', 'ada_related', 0.018),
#  ('Elmwood Trans', 'ada_related', 0.018),
#  ('Midvale Maint', 'ada_related', 0.018),
#  ('Midvale Maint', 'ada_related', 0.018),
#  ('Midvale Maint', 'ada_related', 0.018),
#  ('Claims', 'ada_related', 0.017),
#  ('Claims', 'ada_related', 0.017),
#  ('Claims', 'ada_related', 0.017),
#  ('Public/Gov. Affairs', 'titleiv', 0.017),
#  ('Public/Gov. Affairs', 'titleiv', 0.017),
#  ('Public/Gov. Affairs', 'titleiv', 0.017),
#  ('WTR', 'request_refund', 0.017),
#  ('WTR', 'request_refund', 0.017),
#  ('WTR', 'request_refund', 0.017),
#  ('FOX', 'ada_related', 0.017),
#  ('FOX', 'ada_related', 0.017),
#  ('FOX', 'ada_related', 0.017),
#  ('Victory Trans', 'weather_related', 0.016),
#  ('Victory Trans', 'weather_related', 0.016),
#  ('Victory Trans', 'weather_related', 0.016),
#  ('RR Center', 'ada_related', 0.016),
#  ('RR Center', 'ada_related', 0.016),
#  ('RR Center', 'ada_related', 0.016),
#  ('Callowhill Trans', 'detour_related', 0.016),
#  ('Callowhill Trans', 'detour_related', 0.016),
#  ('Callowhill Trans', 'detour_related', 0.016),
#  ('FOX', 'request_refund', 0.016),
#  ('FOX', 'request_refund', 0.016),
#  ('FOX', 'request_refund', 0.016),
#  ('Elmwood Maint', 'ada_related', 0.016),
#  ('Elmwood Maint', 'ada_related', 0.016),
#  ('Elmwood Maint', 'ada_related', 0.016),
#  ('Elmwood Maint', 'request_refund', 0.016),
#  ('Elmwood Maint', 'request_refund', 0.016),
#  ('Elmwood Maint', 'request_refund', 0.016),
#  ('TRE', 'weather_related', 0.015),
#  ('TRE', 'weather_related', 0.015),
#  ('TRE', 'weather_related', 0.015),
#  ('Midvale Trans', 'detour_related', 0.015),
#  ('Midvale Trans', 'detour_related', 0.015),
#  ('Midvale Trans', 'detour_related', 0.015),
#  ('Frontier Trans', 'weather_related', 0.015),
#  ('Frontier Trans', 'weather_related', 0.015),
#  ('Frontier Trans', 'weather_related', 0.015),
#  ('WTR', 'weather_related', 0.015),
#  ('WTR', 'weather_related', 0.015),
#  ('WTR', 'weather_related', 0.015),
#  ('CHW', 'request_refund', 0.015),
#  ('CHW', 'request_refund', 0.015),
#  ('CHW', 'request_refund', 0.015),
#  ('AIR', 'weather_related', 0.014),
#  ('AIR', 'weather_related', 0.014),
#  ('AIR', 'weather_related', 0.014),
#  ('Revenue Operations', 'ada_related', 0.014),
#  ('Revenue Operations', 'ada_related', 0.014),
#  ('Revenue Operations', 'ada_related', 0.014),
#  ('BSL Trans', 'request_refund', 0.014),
#  ('BSL Trans', 'request_refund', 0.014),
#  ('BSL Trans', 'request_refund', 0.014),
#  ('RR Center', 'weather_related', 0.014),
#  ('RR Center', 'weather_related', 0.014),
#  ('RR Center', 'weather_related', 0.014),
#  ('CHE', 'weather_related', 0.013),
#  ('CHE', 'weather_related', 0.013),
#  ('CHE', 'weather_related', 0.013),
#  ('Frankford Trans', 'weather_related', 0.013),
#  ('Frankford Trans', 'weather_related', 0.013),
#  ('Frankford Trans', 'weather_related', 0.013),
#  ('WAR', 'weather_related', 0.013),
#  ('WAR', 'weather_related', 0.013),
#  ('WAR', 'weather_related', 0.013),
#  ('Comly Trans', 'weather_related', 0.013),
#  ('Comly Trans', 'weather_related', 0.013),
#  ('Comly Trans', 'weather_related', 0.013),
#  ('Allegheny Trans', 'weather_related', 0.013),
#  ('Allegheny Trans', 'weather_related', 0.013),
#  ('Allegheny Trans', 'weather_related', 0.013),
#  ('Callowhill Trans', 'weather_related', 0.013),
#  ('Callowhill Trans', 'weather_related', 0.013),
#  ('Callowhill Trans', 'weather_related', 0.013),
#  ('Control Center', 'detour_related', 0.013),
#  ('Control Center', 'detour_related', 0.013),
#  ('Control Center', 'detour_related', 0.013),
#  ('Serv Plan Strategic', 'esms', 0.013),
#  ('Serv Plan Strategic', 'esms', 0.013),
#  ('Serv Plan Strategic', 'esms', 0.013),
#  ('SubEl Stations', 'weather_related', 0.012),
#  ('SubEl Stations', 'weather_related', 0.012),
#  ('SubEl Stations', 'weather_related', 0.012),
#  ('Contract Ops', 'weather_related', 0.012),
#  ('Contract Ops', 'weather_related', 0.012),
#  ('Contract Ops', 'weather_related', 0.012),
#  ('Southern Maint', 'weather_related', 0.012),
#  ('Southern Maint', 'weather_related', 0.012),
#  ('Southern Maint', 'weather_related', 0.012),
#  ('WIL', 'ada_related', 0.012),
#  ('WIL', 'ada_related', 0.012),
#  ('WIL', 'ada_related', 0.012),
#  ('Communications', 'ada_related', 0.012),
#  ('Communications', 'ada_related', 0.012),
#  ('Communications', 'ada_related', 0.012),
#  ('Comly Maint', 'ada_related', 0.012),
#  ('Comly Maint', 'ada_related', 0.012),
#  ('Comly Maint', 'ada_related', 0.012),
#  ('Customer Service', 'detour_related', 0.011),
#  ('Customer Service', 'detour_related', 0.011),
#  ('Customer Service', 'detour_related', 0.011),
#  ('Customer Service', 'weather_related', 0.011),
#  ('Customer Service', 'weather_related', 0.011),
#  ('Customer Service', 'weather_related', 0.011),
#  ('DOY', 'weather_related', 0.011),
#  ('DOY', 'weather_related', 0.011),
#  ('DOY', 'weather_related', 0.011),
#  ('HR', 'titleiv', 0.011),
#  ('HR', 'titleiv', 0.011),
#  ('HR', 'titleiv', 0.011),
#  ('Frankford Trans', 'detour_related', 0.011),
#  ('Frankford Trans', 'detour_related', 0.011),
#  ('Frankford Trans', 'detour_related', 0.011),
#  ('AIR', 'ada_related', 0.011),
#  ('AIR', 'ada_related', 0.011),
#  ('AIR', 'ada_related', 0.011),
#  ('RR Rev', 'ada_related', 0.011),
#  ('RR Rev', 'ada_related', 0.011),
#  ('RR Rev', 'ada_related', 0.011),
#  ('ELW', 'ada_related', 0.011),
#  ('ELW', 'ada_related', 0.011),
#  ('ELW', 'ada_related', 0.011),
#  ('RR Maint', 'esms', 0.011),
#  ('RR Maint', 'esms', 0.011),
#  ('RR Maint', 'esms', 0.011),
#  ('Elmwood Trans', 'weather_related', 0.011),
#  ('Elmwood Trans', 'weather_related', 0.011),
#  ('Elmwood Trans', 'weather_related', 0.011),
#  ('CHW', 'ada_related', 0.011),
#  ('CHW', 'ada_related', 0.011),
#  ('CHW', 'ada_related', 0.011),
#  ('SubEl Stations', 'titleiv', 0.01),
#  ('SubEl Stations', 'titleiv', 0.01),
#  ('SubEl Stations', 'titleiv', 0.01),
#  ('Southern Trans', 'weather_related', 0.01),
#  ('Southern Trans', 'weather_related', 0.01),
#  ('Southern Trans', 'weather_related', 0.01),
#  ('Contract Ops', 'ada_related', 0.01),
#  ('Contract Ops', 'ada_related', 0.01),
#  ('Contract Ops', 'ada_related', 0.01),
#  ('WTR', 'ada_related', 0.01),
#  ('WTR', 'ada_related', 0.01),
#  ('WTR', 'ada_related', 0.01),
#  ('Serv Plan Sched', 'weather_related', 0.01),
#  ('Serv Plan Sched', 'weather_related', 0.01),
#  ('Serv Plan Sched', 'weather_related', 0.01),
#  ('Victory Maint', 'ada_related', 0.01),
#  ('Victory Maint', 'ada_related', 0.01),
#  ('Victory Maint', 'ada_related', 0.01),
#  ('Victory Maint', 'request_refund', 0.01),
#  ('Victory Maint', 'request_refund', 0.01),
#  ('Victory Maint', 'request_refund', 0.01),
#  ('MFL Trans', 'weather_related', 0.009),
#  ('MFL Trans', 'weather_related', 0.009),
#  ('MFL Trans', 'weather_related', 0.009),
#  ('MFL Trans', 'request_refund', 0.009),
#  ('MFL Trans', 'request_refund', 0.009),
#  ('MFL Trans', 'request_refund', 0.009),
#  ('TRE', 'ada_related', 0.009),
#  ('TRE', 'ada_related', 0.009),
#  ('TRE', 'ada_related', 0.009),
#  ('DOY', 'ada_related', 0.009),
#  ('DOY', 'ada_related', 0.009),
#  ('DOY', 'ada_related', 0.009),
#  ('Frankford Maint', 'weather_related', 0.009),
#  ('Frankford Maint', 'weather_related', 0.009),
#  ('Frankford Maint', 'weather_related', 0.009),
#  ('Claims', 'esms', 0.009),
#  ('Claims', 'esms', 0.009),
#  ('Claims', 'esms', 0.009),
#  ('WAR', 'ada_related', 0.009),
#  ('WAR', 'ada_related', 0.009),
#  ('WAR', 'ada_related', 0.009),
#  ('Wyoming', 'weather_related', 0.009),
#  ('Wyoming', 'weather_related', 0.009),
#  ('Wyoming', 'weather_related', 0.009),
#  ('MFL Maint', 'weather_related', 0.009),
#  ('MFL Maint', 'weather_related', 0.009),
#  ('MFL Maint', 'weather_related', 0.009),
#  ('MFL Maint', 'esms', 0.009),
#  ('MFL Maint', 'esms', 0.009),
#  ('MFL Maint', 'esms', 0.009),
#  ('RR Center', 'request_refund', 0.009),
#  ('RR Center', 'request_refund', 0.009),
#  ('RR Center', 'request_refund', 0.009),
#  ('Public/Gov. Affairs', 'esms', 0.009),
#  ('Public/Gov. Affairs', 'esms', 0.009),
#  ('Public/Gov. Affairs', 'esms', 0.009),
#  ('FOX', 'titleiv', 0.009),
#  ('FOX', 'titleiv', 0.009),
#  ('FOX', 'titleiv', 0.009),
#  ('Victory Service', 'weather_related', 0.009),
#  ('Victory Service', 'weather_related', 0.009),
#  ('Victory Service', 'weather_related', 0.009),
#  ('Frontier Service', 'ada_related', 0.009),
#  ('Frontier Service', 'ada_related', 0.009),
#  ('Frontier Service', 'ada_related', 0.009),
#  ('Septa Key Call Center', 'ada_related', 0.009),
#  ('Septa Key Call Center', 'ada_related', 0.009),
#  ('Septa Key Call Center', 'ada_related', 0.009),
#  ('MFL Maint', 'request_refund', 0.008),
#  ('MFL Maint', 'request_refund', 0.008),
#  ('MFL Maint', 'request_refund', 0.008),
#  ('Serv Plan Sched', 'detour_related', 0.008),
#  ('Serv Plan Sched', 'detour_related', 0.008),
#  ('Serv Plan Sched', 'detour_related', 0.008),
#  ('SubEl Stations', 'esms', 0.007),
#  ('SubEl Stations', 'esms', 0.007),
#  ('SubEl Stations', 'esms', 0.007),
#  ('MFL Trans', 'ada_related', 0.007),
#  ('MFL Trans', 'ada_related', 0.007),
#  ('MFL Trans', 'ada_related', 0.007),
#  ('Frankford Trans', 'titleiv', 0.007),
#  ('Frankford Trans', 'titleiv', 0.007),
#  ('Frankford Trans', 'titleiv', 0.007),
#  ('AIR', 'titleiv', 0.007),
#  ('AIR', 'titleiv', 0.007),
#  ('AIR', 'titleiv', 0.007),
#  ('Parking Operations', 'weather_related', 0.007),
#  ('Parking Operations', 'weather_related', 0.007),
#  ('Parking Operations', 'weather_related', 0.007),
#  ('Parking Operations', 'request_refund', 0.007),
#  ('Parking Operations', 'request_refund', 0.007),
#  ('Parking Operations', 'request_refund', 0.007),
#  ('Callowhill Maint', 'ada_related', 0.007),
#  ('Callowhill Maint', 'ada_related', 0.007),
#  ('Callowhill Maint', 'ada_related', 0.007),
#  ('Callowhill Maint', 'weather_related', 0.007),
#  ('Callowhill Maint', 'weather_related', 0.007),
#  ('Callowhill Maint', 'weather_related', 0.007),
#  ('Midvale Maint', 'esms', 0.007),
#  ('Midvale Maint', 'esms', 0.007),
#  ('Midvale Maint', 'esms', 0.007),
#  ('CHE', 'ada_related', 0.006),
#  ('CHE', 'ada_related', 0.006),
#  ('CHE', 'ada_related', 0.006),
#  ('Customer Service', 'ada_related', 0.006),
#  ('Customer Service', 'ada_related', 0.006),
#  ('Customer Service', 'ada_related', 0.006),
#  ('PAO', 'ada_related', 0.006),
#  ('PAO', 'ada_related', 0.006),
#  ('PAO', 'ada_related', 0.006),
#  ('RR Rev', 'weather_related', 0.006),
#  ('RR Rev', 'weather_related', 0.006),
#  ('RR Rev', 'weather_related', 0.006),
#  ('IT', 'detour_related', 0.006),
#  ('IT', 'detour_related', 0.006),
#  ('IT', 'detour_related', 0.006),
#  ('Contract Ops', 'esms', 0.006),
#  ('Contract Ops', 'esms', 0.006),
#  ('Contract Ops', 'esms', 0.006),
#  ('Frontier Trans', 'detour_related', 0.006),
#  ('Frontier Trans', 'detour_related', 0.006),
#  ('Frontier Trans', 'detour_related', 0.006),
#  ('Southern Maint', 'ada_related', 0.006),
#  ('Southern Maint', 'ada_related', 0.006),
#  ('Southern Maint', 'ada_related', 0.006),
#  ('Southern Maint', 'detour_related', 0.006),
#  ('Southern Maint', 'detour_related', 0.006),
#  ('Southern Maint', 'detour_related', 0.006),
#  ('Southern Maint', 'request_refund', 0.006),
#  ('Southern Maint', 'request_refund', 0.006),
#  ('Southern Maint', 'request_refund', 0.006),
#  ('Elmwood Trans', 'titleiv', 0.006),
#  ('Elmwood Trans', 'titleiv', 0.006),
#  ('Elmwood Trans', 'titleiv', 0.006),
#  ('Allegheny Maint', 'ada_related', 0.006),
#  ('Allegheny Maint', 'ada_related', 0.006),
#  ('Allegheny Maint', 'ada_related', 0.006),
#  ('Allegheny Maint', 'weather_related', 0.006),
#  ('Allegheny Maint', 'weather_related', 0.006),
#  ('Allegheny Maint', 'weather_related', 0.006),
#  ('Communications', 'detour_related', 0.006),
#  ('Communications', 'detour_related', 0.006),
#  ('Communications', 'detour_related', 0.006),
#  ('Comly Maint', 'request_refund', 0.006),
#  ('Comly Maint', 'request_refund', 0.006),
#  ('Comly Maint', 'request_refund', 0.006),
#  ('Serv Plan Strategic', 'ada_related', 0.006),
#  ('Serv Plan Strategic', 'ada_related', 0.006),
#  ('Serv Plan Strategic', 'ada_related', 0.006),
#  ('Victory Service', 'ada_related', 0.006),
#  ('Victory Service', 'ada_related', 0.006),
#  ('Victory Service', 'ada_related', 0.006),
#  ('Victory Service', 'request_refund', 0.006),
#  ('Victory Service', 'request_refund', 0.006),
#  ('Victory Service', 'request_refund', 0.006),
#  ('Southern Trans', 'request_refund', 0.005),
#  ('Southern Trans', 'request_refund', 0.005),
#  ('Southern Trans', 'request_refund', 0.005),
#  ('Victory Trans', 'request_refund', 0.005),
#  ('Victory Trans', 'request_refund', 0.005),
#  ('Victory Trans', 'request_refund', 0.005),
#  ('Claims', 'request_refund', 0.005),
#  ('Claims', 'request_refund', 0.005),
#  ('Claims', 'request_refund', 0.005),
#  ('Comly Trans', 'detour_related', 0.005),
#  ('Comly Trans', 'detour_related', 0.005),
#  ('Comly Trans', 'detour_related', 0.005),
#  ('Comly Trans', 'titleiv', 0.005),
#  ('Comly Trans', 'titleiv', 0.005),
#  ('Comly Trans', 'titleiv', 0.005),
#  ('BSL Trans', 'ada_related', 0.005),
#  ('BSL Trans', 'ada_related', 0.005),
#  ('BSL Trans', 'ada_related', 0.005),
#  ('Frontier Trans', 'request_refund', 0.005),
#  ('Frontier Trans', 'request_refund', 0.005),
#  ('Frontier Trans', 'request_refund', 0.005),
#  ('Frontier Trans', 'titleiv', 0.005),
#  ('Frontier Trans', 'titleiv', 0.005),
#  ('Frontier Trans', 'titleiv', 0.005),
#  ('Sales', 'weather_related', 0.005),
#  ('Sales', 'weather_related', 0.005),
#  ('Sales', 'weather_related', 0.005),
#  ('Serv Plan City', 'detour_related', 0.005),
#  ('Serv Plan City', 'detour_related', 0.005),
#  ('Serv Plan City', 'detour_related', 0.005),
#  ('Serv Plan City', 'weather_related', 0.005),
#  ('Serv Plan City', 'weather_related', 0.005),
#  ('Serv Plan City', 'weather_related', 0.005),
#  ('Victory Maint', 'detour_related', 0.005),
#  ('Victory Maint', 'detour_related', 0.005),
#  ('Victory Maint', 'detour_related', 0.005),
#  ('Frontier Service', 'weather_related', 0.005),
#  ('Frontier Service', 'weather_related', 0.005),
#  ('Frontier Service', 'weather_related', 0.005),
#  ('CHE', 'request_refund', 0.004),
#  ('CHE', 'request_refund', 0.004),
#  ('CHE', 'request_refund', 0.004),
#  ('CCT', 'weather_related', 0.004),
#  ('CCT', 'weather_related', 0.004),
#  ('CCT', 'weather_related', 0.004),
#  ('CCT', 'request_refund', 0.004),
#  ('CCT', 'request_refund', 0.004),
#  ('CCT', 'request_refund', 0.004),
#  ('Southern Trans', 'titleiv', 0.004),
#  ('Southern Trans', 'titleiv', 0.004),
#  ('Southern Trans', 'titleiv', 0.004),
#  ('Victory Trans', 'detour_related', 0.004),
#  ('Victory Trans', 'detour_related', 0.004),
#  ('Victory Trans', 'detour_related', 0.004),
#  ('Frankford Trans', 'protected_class', 0.004),
#  ('Frankford Trans', 'protected_class', 0.004),
#  ('Frankford Trans', 'protected_class', 0.004),
#  ('BSL Trans', 'weather_related', 0.004),
#  ('BSL Trans', 'weather_related', 0.004),
#  ('BSL Trans', 'weather_related', 0.004),
#  ('Allegheny Trans', 'titleiv', 0.004),
#  ('Allegheny Trans', 'titleiv', 0.004),
#  ('Allegheny Trans', 'titleiv', 0.004),
#  ('Wyoming', 'request_refund', 0.004),
#  ('Wyoming', 'request_refund', 0.004),
#  ('Wyoming', 'request_refund', 0.004),
#  ('MFL Maint', 'ada_related', 0.004),
#  ('MFL Maint', 'ada_related', 0.004),
#  ('MFL Maint', 'ada_related', 0.004),
#  ('BSL Maint', 'esms', 0.004),
#  ('BSL Maint', 'esms', 0.004),
#  ('BSL Maint', 'esms', 0.004),
#  ('Serv Plan RR', 'request_refund', 0.004),
#  ('Serv Plan RR', 'request_refund', 0.004),
#  ('Serv Plan RR', 'request_refund', 0.004),
#  ('Elmwood Trans', 'detour_related', 0.004),
#  ('Elmwood Trans', 'detour_related', 0.004),
#  ('Elmwood Trans', 'detour_related', 0.004),
#  ('Midvale Maint', 'request_refund', 0.004),
#  ('Midvale Maint', 'request_refund', 0.004),
#  ('Midvale Maint', 'request_refund', 0.004),
#  ('Midvale Maint', 'titleiv', 0.004),
#  ('Midvale Maint', 'titleiv', 0.004),
#  ('Midvale Maint', 'titleiv', 0.004),
#  ('CHW', 'titleiv', 0.004),
#  ('CHW', 'titleiv', 0.004),
#  ('CHW', 'titleiv', 0.004),
#  ('Police', 'request_refund', 0.003),
#  ('Police', 'request_refund', 0.003),
#  ('Police', 'request_refund', 0.003),
#  ('SubEl Stations', 'protected_class', 0.003),
#  ('SubEl Stations', 'protected_class', 0.003),
#  ('SubEl Stations', 'protected_class', 0.003),
#  ('Victory Trans', 'titleiv', 0.003),
#  ('Victory Trans', 'titleiv', 0.003),
#  ('Victory Trans', 'titleiv', 0.003),
#  ('Midvale Trans', 'request_refund', 0.003),
#  ('Midvale Trans', 'request_refund', 0.003),
#  ('Midvale Trans', 'request_refund', 0.003),
#  ('Midvale Trans', 'titleiv', 0.003),
#  ('Midvale Trans', 'titleiv', 0.003),
#  ('Midvale Trans', 'titleiv', 0.003),
#  ('Frankford Trans', 'request_refund', 0.003),
#  ('Frankford Trans', 'request_refund', 0.003),
#  ('Frankford Trans', 'request_refund', 0.003),
#  ('Revenue Operations', 'weather_related', 0.003),
#  ('Revenue Operations', 'weather_related', 0.003),
#  ('Revenue Operations', 'weather_related', 0.003),
#  ('RR Rev', 'titleiv', 0.003),
#  ('RR Rev', 'titleiv', 0.003),
#  ('RR Rev', 'titleiv', 0.003),
#  ('Comly Trans', 'protected_class', 0.003),
#  ('Comly Trans', 'protected_class', 0.003),
#  ('Comly Trans', 'protected_class', 0.003),
#  ('Allegheny Trans', 'request_refund', 0.003),
#  ('Allegheny Trans', 'request_refund', 0.003),
#  ('Allegheny Trans', 'request_refund', 0.003),
#  ('Serv Plan RR', 'ada_related', 0.003),
#  ('Serv Plan RR', 'ada_related', 0.003),
#  ('Serv Plan RR', 'ada_related', 0.003),
#  ('NOR', 'ada_related', 0.003),
#  ('NOR', 'ada_related', 0.003),
#  ('NOR', 'ada_related', 0.003),
#  ('Callowhill Trans', 'esms', 0.003),
#  ('Callowhill Trans', 'esms', 0.003),
#  ('Callowhill Trans', 'esms', 0.003),
#  ('Callowhill Trans', 'titleiv', 0.003),
#  ('Callowhill Trans', 'titleiv', 0.003),
#  ('Callowhill Trans', 'titleiv', 0.003),
#  ('RR Maint', 'ada_related', 0.003),
#  ('RR Maint', 'ada_related', 0.003),
#  ('RR Maint', 'ada_related', 0.003),
#  ('Sales', 'titleiv', 0.003),
#  ('Sales', 'titleiv', 0.003),
#  ('Sales', 'titleiv', 0.003),
#  ('Serv Plan Suburb', 'ada_related', 0.003),
#  ('Serv Plan Suburb', 'ada_related', 0.003),
#  ('Serv Plan Suburb', 'ada_related', 0.003),
#  ('Elmwood Trans', 'request_refund', 0.003),
#  ('Elmwood Trans', 'request_refund', 0.003),
#  ('Elmwood Trans', 'request_refund', 0.003),
#  ('Police', 'esms', 0.002),
#  ('Police', 'esms', 0.002),
#  ('Police', 'esms', 0.002),
#  ('Southern Trans', 'esms', 0.002),
#  ('Southern Trans', 'esms', 0.002),
#  ('Southern Trans', 'esms', 0.002),
#  ('Claims', 'detour_related', 0.002),
#  ('Claims', 'detour_related', 0.002),
#  ('Claims', 'detour_related', 0.002),
#  ('PAO', 'titleiv', 0.002),
#  ('PAO', 'titleiv', 0.002),
#  ('PAO', 'titleiv', 0.002),
#  ('Revenue Operations', 'titleiv', 0.002),
#  ('Revenue Operations', 'titleiv', 0.002),
#  ('Revenue Operations', 'titleiv', 0.002),
#  ('Key Development', 'titleiv', 0.002),
#  ('Key Development', 'titleiv', 0.002),
#  ('Key Development', 'titleiv', 0.002),
#  ('Comly Trans', 'request_refund', 0.002),
#  ('Comly Trans', 'request_refund', 0.002),
#  ('Comly Trans', 'request_refund', 0.002),
#  ('IT', 'ada_related', 0.002),
#  ('IT', 'ada_related', 0.002),
#  ('IT', 'ada_related', 0.002),
#  ('Wyoming', 'ada_related', 0.002),
#  ('Wyoming', 'ada_related', 0.002),
#  ('Wyoming', 'ada_related', 0.002),
#  ('Frontier Trans', 'protected_class', 0.002),
#  ('Frontier Trans', 'protected_class', 0.002),
#  ('Frontier Trans', 'protected_class', 0.002),
#  ('RR Center', 'titleiv', 0.002),
#  ('RR Center', 'titleiv', 0.002),
#  ('RR Center', 'titleiv', 0.002),
#  ('Callowhill Trans', 'request_refund', 0.002),
#  ('Callowhill Trans', 'request_refund', 0.002),
#  ('Callowhill Trans', 'request_refund', 0.002),
#  ('ELW', 'titleiv', 0.002),
#  ('ELW', 'titleiv', 0.002),
#  ('ELW', 'titleiv', 0.002),
#  ('Sales', 'ada_related', 0.002),
#  ('Sales', 'ada_related', 0.002),
#  ('Sales', 'ada_related', 0.002),
#  ('WIL', 'titleiv', 0.002),
#  ('WIL', 'titleiv', 0.002),
#  ('WIL', 'titleiv', 0.002),
#  ('Serv Plan Suburb', 'weather_related', 0.002),
#  ('Serv Plan Suburb', 'weather_related', 0.002),
#  ('Serv Plan Suburb', 'weather_related', 0.002),
#  ('Serv Plan Suburb', 'request_refund', 0.002),
#  ('Serv Plan Suburb', 'request_refund', 0.002),
#  ('Serv Plan Suburb', 'request_refund', 0.002),
#  ('CHW', 'esms', 0.002),
#  ('CHW', 'esms', 0.002),
#  ('CHW', 'esms', 0.002),
#  ('Septa Key Call Center', 'detour_related', 0.002),
#  ('Septa Key Call Center', 'detour_related', 0.002),
#  ('Septa Key Call Center', 'detour_related', 0.002),
#  ('Septa Key Call Center', 'weather_related', 0.002),
#  ('Septa Key Call Center', 'weather_related', 0.002),
#  ('Septa Key Call Center', 'weather_related', 0.002),
#  ('Police', 'ada_related', 0.001),
#  ('Police', 'ada_related', 0.001),
#  ('Police', 'ada_related', 0.001),
#  ('Police', 'weather_related', 0.001),
#  ('Police', 'weather_related', 0.001),
#  ('Police', 'weather_related', 0.001),
#  ('CCT', 'esms', 0.001),
#  ('CCT', 'esms', 0.001),
#  ('CCT', 'esms', 0.001),
#  ('CCT', 'titleiv', 0.001),
#  ('CCT', 'titleiv', 0.001),
#  ('CCT', 'titleiv', 0.001),
#  ('Customer Service', 'esms', 0.001),
#  ('Customer Service', 'esms', 0.001),
#  ('Customer Service', 'esms', 0.001),
#  ('Southern Trans', 'protected_class', 0.001),
#  ('Southern Trans', 'protected_class', 0.001),
#  ('Southern Trans', 'protected_class', 0.001),
#  ('Victory Trans', 'esms', 0.001),
#  ('Victory Trans', 'esms', 0.001),
#  ('Victory Trans', 'esms', 0.001),
#  ('Midvale Trans', 'esms', 0.001),
#  ('Midvale Trans', 'esms', 0.001),
#  ('Midvale Trans', 'esms', 0.001),
#  ('Midvale Trans', 'protected_class', 0.001),
#  ('Midvale Trans', 'protected_class', 0.001),
#  ('Midvale Trans', 'protected_class', 0.001),
#  ('DOY', 'esms', 0.001),
#  ('DOY', 'esms', 0.001),
#  ('DOY', 'esms', 0.001),
#  ('Claims', 'titleiv', 0.001),
#  ('Claims', 'titleiv', 0.001),
#  ('Claims', 'titleiv', 0.001),
#  ('Claims', 'protected_class', 0.001),
#  ('Claims', 'protected_class', 0.001),
#  ('Claims', 'protected_class', 0.001),
#  ('Frankford Trans', 'esms', 0.001),
#  ('Frankford Trans', 'esms', 0.001),
#  ('Frankford Trans', 'esms', 0.001),
#  ('WAR', 'esms', 0.001),
#  ('WAR', 'esms', 0.001),
#  ('WAR', 'esms', 0.001),
#  ('WAR', 'titleiv', 0.001),
#  ('WAR', 'titleiv', 0.001),
#  ('WAR', 'titleiv', 0.001),
#  ('PAO', 'protected_class', 0.001),
#  ('PAO', 'protected_class', 0.001),
#  ('PAO', 'protected_class', 0.001),
#  ('RR Rev', 'protected_class', 0.001),
#  ('RR Rev', 'protected_class', 0.001),
#  ('RR Rev', 'protected_class', 0.001),
#  ('Comly Trans', 'esms', 0.001),
#  ('Comly Trans', 'esms', 0.001),
#  ('Comly Trans', 'esms', 0.001),
#  ('IT', 'weather_related', 0.001),
#  ('IT', 'weather_related', 0.001),
#  ('IT', 'weather_related', 0.001),
#  ('IT', 'request_refund', 0.001),
#  ('IT', 'request_refund', 0.001),
#  ('IT', 'request_refund', 0.001),
#  ('Allegheny Trans', 'protected_class', 0.001),
#  ('Allegheny Trans', 'protected_class', 0.001),
#  ('Allegheny Trans', 'protected_class', 0.001),
#  ('EM & C', 'detour_related', 0.001),
#  ('EM & C', 'detour_related', 0.001),
#  ('EM & C', 'detour_related', 0.001),
#  ('EM & C', 'request_refund', 0.001),
#  ('EM & C', 'request_refund', 0.001),
#  ('EM & C', 'request_refund', 0.001),
#  ('EM & C', 'titleiv', 0.001),
#  ('EM & C', 'titleiv', 0.001),
#  ('EM & C', 'titleiv', 0.001),
#  ('Parking Operations', 'esms', 0.001),
#  ('Parking Operations', 'esms', 0.001),
#  ('Parking Operations', 'esms', 0.001),
#  ('RR Center', 'esms', 0.001),
#  ('RR Center', 'esms', 0.001),
#  ('RR Center', 'esms', 0.001),
#  ('RR Center', 'protected_class', 0.001),
#  ('RR Center', 'protected_class', 0.001),
#  ('RR Center', 'protected_class', 0.001),
#  ('NOR', 'titleiv', 0.001),
#  ('NOR', 'titleiv', 0.001),
#  ('NOR', 'titleiv', 0.001),
#  ('Callowhill Trans', 'protected_class', 0.001),
#  ('Callowhill Trans', 'protected_class', 0.001),
#  ('Callowhill Trans', 'protected_class', 0.001),
#  ('Control Center', 'ada_related', 0.001),
#  ('Control Center', 'ada_related', 0.001),
#  ('Control Center', 'ada_related', 0.001),
#  ('ELW', 'esms', 0.001),
#  ('ELW', 'esms', 0.001),
#  ('ELW', 'esms', 0.001),
#  ('ELW', 'protected_class', 0.001),
#  ('ELW', 'protected_class', 0.001),
#  ('ELW', 'protected_class', 0.001),
#  ('Sales', 'detour_related', 0.001),
#  ('Sales', 'detour_related', 0.001),
#  ('Sales', 'detour_related', 0.001),
#  ('WIL', 'esms', 0.001),
#  ('WIL', 'esms', 0.001),
#  ('WIL', 'esms', 0.001),
#  ('WTR', 'titleiv', 0.001),
#  ('WTR', 'titleiv', 0.001),
#  ('WTR', 'titleiv', 0.001),
#  ('Elmwood Trans', 'protected_class', 0.001),
#  ('Elmwood Trans', 'protected_class', 0.001),
#  ('Elmwood Trans', 'protected_class', 0.001),
#  ('FOX', 'protected_class', 0.001),
#  ('FOX', 'protected_class', 0.001),
#  ('FOX', 'protected_class', 0.001),
#  ('Serv Plan City', 'ada_related', 0.001),
#  ('Serv Plan City', 'ada_related', 0.001),
#  ('Serv Plan City', 'ada_related', 0.001),
#  ('Serv Plan City', 'titleiv', 0.001),
#  ('Serv Plan City', 'titleiv', 0.001),
#  ('Serv Plan City', 'titleiv', 0.001),
#  ('Victory Service', 'esms', 0.001),
#  ('Victory Service', 'esms', 0.001),
#  ('Victory Service', 'esms', 0.001),
#  ('Police', 'detour_related', 0.0),
#  ('Police', 'detour_related', 0.0),
#  ('Police', 'titleiv', 0.0),
#  ('Police', 'titleiv', 0.0),
#  ('Police', 'titleiv', 0.0),
#  ('Police', 'protected_class', 0.0),
#  ('Police', 'protected_class', 0.0),
#  ('CHE', 'detour_related', 0.0),
#  ('CHE', 'detour_related', 0.0),
#  ('CHE', 'esms', 0.0),
#  ('CHE', 'esms', 0.0),
#  ('CHE', 'titleiv', 0.0),
#  ('CHE', 'titleiv', 0.0),
#  ('CHE', 'protected_class', 0.0),
#  ('CHE', 'protected_class', 0.0),
#  ('CCT', 'detour_related', 0.0),
#  ('CCT', 'detour_related', 0.0),
#  ('CCT', 'protected_class', 0.0),
#  ('CCT', 'protected_class', 0.0),
#  ('Customer Service', 'titleiv', 0.0),
#  ('Customer Service', 'titleiv', 0.0),
#  ('Customer Service', 'titleiv', 0.0),
#  ('Customer Service', 'protected_class', 0.0),
#  ('Customer Service', 'protected_class', 0.0),
#  ('Customer Service', 'protected_class', 0.0),
#  ('SubEl Stations', 'detour_related', 0.0),
#  ('SubEl Stations', 'detour_related', 0.0),
#  ('MFL Trans', 'detour_related', 0.0),
#  ('MFL Trans', 'detour_related', 0.0),
#  ('MFL Trans', 'esms', 0.0),
#  ('MFL Trans', 'esms', 0.0),
#  ('MFL Trans', 'titleiv', 0.0),
#  ('MFL Trans', 'titleiv', 0.0),
#  ('MFL Trans', 'protected_class', 0.0),
#  ('MFL Trans', 'protected_class', 0.0),
#  ('TRE', 'detour_related', 0.0),
#  ('TRE', 'detour_related', 0.0),
#  ('TRE', 'esms', 0.0),
#  ('TRE', 'esms', 0.0),
#  ('TRE', 'titleiv', 0.0),
#  ('TRE', 'titleiv', 0.0),
#  ('TRE', 'protected_class', 0.0),
#  ('TRE', 'protected_class', 0.0),
#  ('Victory Trans', 'protected_class', 0.0),
#  ('Victory Trans', 'protected_class', 0.0),
#  ('Victory Trans', 'protected_class', 0.0),
#  ('DOY', 'detour_related', 0.0),
#  ('DOY', 'detour_related', 0.0),
#  ('DOY', 'titleiv', 0.0),
#  ('DOY', 'titleiv', 0.0),
#  ('DOY', 'protected_class', 0.0),
#  ('DOY', 'protected_class', 0.0),
#  ('Frankford Maint', 'ada_related', 0.0),
#  ('Frankford Maint', 'ada_related', 0.0),
#  ('Frankford Maint', 'detour_related', 0.0),
#  ('Frankford Maint', 'detour_related', 0.0),
#  ('Frankford Maint', 'request_refund', 0.0),
#  ('Frankford Maint', 'request_refund', 0.0),
#  ('Frankford Maint', 'esms', 0.0),
#  ('Frankford Maint', 'esms', 0.0),
#  ('Frankford Maint', 'titleiv', 0.0),
#  ('Frankford Maint', 'titleiv', 0.0),
#  ('Frankford Maint', 'protected_class', 0.0),
#  ('Frankford Maint', 'protected_class', 0.0),
#  ('CYN', 'detour_related', 0.0),
#  ('CYN', 'detour_related', 0.0),
#  ('CYN', 'request_refund', 0.0),
#  ('CYN', 'request_refund', 0.0),
#  ('CYN', 'esms', 0.0),
#  ('CYN', 'esms', 0.0),
#  ('CYN', 'titleiv', 0.0),
#  ('CYN', 'titleiv', 0.0),
#  ('CYN', 'protected_class', 0.0),
#  ('CYN', 'protected_class', 0.0),
#  ('HR', 'ada_related', 0.0),
#  ('HR', 'ada_related', 0.0),
#  ('HR', 'detour_related', 0.0),
#  ('HR', 'detour_related', 0.0),
#  ('HR', 'weather_related', 0.0),
#  ('HR', 'weather_related', 0.0),
#  ('HR', 'request_refund', 0.0),
#  ('HR', 'request_refund', 0.0),
#  ('HR', 'esms', 0.0),
#  ('HR', 'esms', 0.0),
#  ('HR', 'protected_class', 0.0),
#  ('HR', 'protected_class', 0.0),
#  ('AIR', 'detour_related', 0.0),
#  ('AIR', 'detour_related', 0.0),
#  ('AIR', 'esms', 0.0),
#  ('AIR', 'esms', 0.0),
#  ('AIR', 'protected_class', 0.0),
#  ('AIR', 'protected_class', 0.0),
#  ('WAR', 'detour_related', 0.0),
#  ('WAR', 'detour_related', 0.0),
#  ('WAR', 'protected_class', 0.0),
#  ('WAR', 'protected_class', 0.0),
#  ('PAO', 'detour_related', 0.0),
#  ('PAO', 'detour_related', 0.0),
#  ('PAO', 'esms', 0.0),
#  ('PAO', 'esms', 0.0),
#  ('PAO', 'esms', 0.0),
#  ('Revenue Operations', 'detour_related', 0.0),
#  ('Revenue Operations', 'detour_related', 0.0),
#  ('Revenue Operations', 'esms', 0.0),
#  ('Revenue Operations', 'esms', 0.0),
#  ('Revenue Operations', 'protected_class', 0.0),
#  ('Revenue Operations', 'protected_class', 0.0),
#  ('Key Development', 'detour_related', 0.0),
#  ('Key Development', 'detour_related', 0.0),
#  ('Key Development', 'weather_related', 0.0),
#  ('Key Development', 'weather_related', 0.0),
#  ('Key Development', 'esms', 0.0),
#  ('Key Development', 'esms', 0.0),
#  ('Key Development', 'protected_class', 0.0),
#  ('Key Development', 'protected_class', 0.0),
#  ('RR Rev', 'detour_related', 0.0),
#  ('RR Rev', 'detour_related', 0.0),
#  ('RR Rev', 'esms', 0.0),
#  ('RR Rev', 'esms', 0.0),
#  ('BSL Trans', 'detour_related', 0.0),
#  ('BSL Trans', 'detour_related', 0.0),
#  ('BSL Trans', 'esms', 0.0),
#  ('BSL Trans', 'esms', 0.0),
#  ('BSL Trans', 'titleiv', 0.0),
#  ('BSL Trans', 'titleiv', 0.0),
#  ('BSL Trans', 'protected_class', 0.0),
#  ('BSL Trans', 'protected_class', 0.0),
#  ('IT', 'esms', 0.0),
#  ('IT', 'esms', 0.0),
#  ('IT', 'titleiv', 0.0),
#  ('IT', 'titleiv', 0.0),
#  ('IT', 'protected_class', 0.0),
#  ('IT', 'protected_class', 0.0),
#  ('Allegheny Trans', 'esms', 0.0),
#  ('Allegheny Trans', 'esms', 0.0),
#  ('EM & C', 'protected_class', 0.0),
#  ('EM & C', 'protected_class', 0.0),
#  ('Wyoming', 'esms', 0.0),
#  ('Wyoming', 'esms', 0.0),
#  ('Wyoming', 'esms', 0.0),
#  ('Wyoming', 'titleiv', 0.0),
#  ('Wyoming', 'titleiv', 0.0),
#  ('Wyoming', 'protected_class', 0.0),
#  ('Wyoming', 'protected_class', 0.0),
#  ('Wyoming', 'protected_class', 0.0),
#  ('Contract Ops', 'detour_related', 0.0),
#  ('Contract Ops', 'detour_related', 0.0),
#  ('Contract Ops', 'request_refund', 0.0),
#  ('Contract Ops', 'request_refund', 0.0),
#  ('Contract Ops', 'titleiv', 0.0),
#  ('Contract Ops', 'titleiv', 0.0),
#  ('Contract Ops', 'protected_class', 0.0),
#  ('Contract Ops', 'protected_class', 0.0),
#  ('Frontier Trans', 'esms', 0.0),
#  ('Frontier Trans', 'esms', 0.0),
#  ('MFL Maint', 'detour_related', 0.0),
#  ('MFL Maint', 'detour_related', 0.0),
#  ('MFL Maint', 'titleiv', 0.0),
#  ('MFL Maint', 'titleiv', 0.0),
#  ('MFL Maint', 'protected_class', 0.0),
#  ('MFL Maint', 'protected_class', 0.0),
#  ('BSL Maint', 'ada_related', 0.0),
#  ('BSL Maint', 'ada_related', 0.0),
#  ('BSL Maint', 'detour_related', 0.0),
#  ('BSL Maint', 'detour_related', 0.0),
#  ('BSL Maint', 'titleiv', 0.0),
#  ('BSL Maint', 'titleiv', 0.0),
#  ('BSL Maint', 'protected_class', 0.0),
#  ('BSL Maint', 'protected_class', 0.0),
#  ...]

# %%
#CELL 8: PREDICTION MODELING: Is our ticket ADA_related ?

# filter our data frame to have tickets that are only ada_related (value = "true")
df3_ada = df3[df3["ada_related"] == 'true']

total = len(df3_ada)
def percents(col):
    for key, value in col.value_counts().iteritems():
        # line below calculates how often a particular attribute of another variable exists when that ticket...
            # is also ADA_related.
        percentage = value / total
        return key, round(percentage,2)
        
# using our filtered data frame, call the "percents" function above to find the most common attributes...
    #... of the other variables on the customer ticket.
most_frequent = df3_ada.apply(percents, axis = 0)

correlations = []
bad_keys = ["cs_ticket_number", "customer_incident_date_time", "customer_text_description", "created_date",
            "ada_related"]

# below we will work to sort all of these variables to see which ones have the highest positive correlation
    # with an ADA related variable.
for key, values in most_frequent.iteritems():
    if values[0] == "" or values[0] == " " or key in bad_keys:
        continue
    else:
        l = []
        l.append(key)
        l.append(values[0])
        l.append(values[1])
        t = tuple(l)
        correlations.append(t)
        
sorted(correlations, key=lambda x: x[2], reverse = True)

# When a ticket is ada_related, it has a 47% probability of 'Bus' being its mode of transportation ... 
     #and a 45% probability it came from the 'Surface Trans' department
# Out:
# [('how_received', 'Web', 1.0),
#  ('detour_related', 'false', 1.0),
#  ('esms', 'false', 1.0),
#  ('titleiv', 'false', 1.0),
#  ('request_refund', 'false', 0.99),
#  ('protected_class', 'false', 0.99),
#  ('status', 'Closed', 0.99),
#  ('weather_related', 'false', 0.98),
#  ('safety_related', 'false', 0.94),
#  ('safety_related', 'false', 0.94),
#  ('type', 'Complaint', 0.58),
#  ('group_code', 'Employee', 0.58),
#  ('mode', 'Bus', 0.47),
#  ('department', 'Surface Trans', 0.45),
#  ('code', '02-job-performance', 0.21),
#  ('location', 'Customer Service', 0.11)]
